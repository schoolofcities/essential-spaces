# %%
import pandas as pd

# %%
df = pd.read_csv("equity_data/ct-data-all-csdjoin.csv")

# %%
df["Rent%"] = 100 * df["Rent_count"] / (df["Rent_count"] + df["Own_count"])

# %%
df
# Out:
#            ctuid  Own_count  Rent_count  Unknown_count  Total_count  \
# 0     5350400.02          0           2              0            2
# 1     5350400.03          0           1              0            1
# 2     5350400.04          0          11              0           11
# 3     5350400.06          0           0              0            0
# 4     5350400.07          0           3              0            3
# ...          ...        ...         ...            ...          ...
# 1060  5350586.03          0           0              0            0
# 1061  5350586.04          0           0              0            0
# 1062  5350586.05          0           0              0            0
# 1063  5350587.01          1           0              0            1
# 1064  5350587.02          1           1              0            2
#
#       Equity Index  Popu_2021  PopuDenPerKM  Immigrant%    VM%  ...  Neet%  \
# ...
